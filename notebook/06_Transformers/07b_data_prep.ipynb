# %% [markdown]
# ## Data Preparation For Sentence Classification

# %%
# Built-in library
import re
import json
import logging
from typing import Any, Dict, List, Optional, Union
import logging
import warnings

# Standard imports
import numpy as np
import pandas as pd
from rich import print
import torch

# Visualization
import matplotlib.pyplot as plt


# Pandas settings
pd.options.display.max_rows = 1_000
pd.options.display.max_columns = 1_000
pd.options.display.max_colwidth = 600

warnings.filterwarnings("ignore")

# Black code formatter (Optional)
# %load_ext lab_black

# auto reload imports
# %load_ext autoreload
# %autoreload 2

# %%
def set_up_logger(delim: str = "::") -> Any:
    """This is used to create a basic logger."""

    format_ = f"[%(levelname)s] {delim} %(asctime)s {delim} %(message)s"
    logging.basicConfig(level=logging.INFO, format=format_)
    logger = logging.getLogger(__name__)
    return logger


# Global variable
logger = set_up_logger()


def load_data(*, filename: str, sep: str = ",") -> pd.DataFrame:
    """This is used to load the data.

    NB: Supported formats are 'csv' and 'parquet'.

    Params:
    -------
        filename (str): The filepath.
        sep (str, default=","): The separator. e.g ',', '\t', etc

    Returns:
    --------
        data (pd.DataFrame): The loaded dataframe.
    """
    data = (
        pd.read_csv(filename, sep=sep)
        if filename.split(".")[-1] == "csv"
        else pd.read_parquet(filename)
    )
    logger.info(f"Shape of data: {data.shape}\n")
    return data

# %% [markdown]
# ### Prepare Data
#
# ```text
# Create:
# - Training data
# - Validation data
# - Test data
#
# Labels
# ------
# salary
# gambling
# loan
# airtime
# ussdTransactions
# flightRisk
# savingsAndInvestments
# entertainment
# spend
#   - posSpend
#   - atmSpend
#   - mobileSpend
#   - webSpend
# ```

# %%
fp: str = "../../data/trans_TAGS_17.parquet"
N: int = 800_000
df: pd.DataFrame = (
    load_data(filename=fp).sample(n=N, random_state=123).reset_index(drop=True)
)

df.head()
# Out:
# [INFO] :: 2023-11-05 20:12:56,650 :: Shape of data: (2390838, 7)
#   customer_id  nuban        date  \
# 0       40837      1  2022-04-19
# 1       39005      1  2022-08-30
# 2       40454      1  2022-07-05
# 3       39318      1  2022-07-08
# 4       38851      1  2022-04-09
#
#                                                           description  \
# 0  TRF/Ac/fan/FRM GIBSON PAUL U TO CHRIS-CHUKKAS ELECTRONICS LTD- 070
# 1                        TRF/Friday /FRM JONAH FRIDAY TO ONYENAUCHEYA
# 2                   Amt includes COMM & VAT/USSD/AISHAT ABIODUN BELLO
# 3       TRF/For clothes/FRM AJAKAYE WUNMI R TO OLALEYE OPEOLUWA LYDIA
# 4                                   WT|KODIRIC GLOBAL ENTERPRAMAC NG
#
#       amount type  \
# 0  163053.75    D
# 1    5010.75    D
# 2    3021.50    D
# 3   24000.00    D
# 4     100.00    D
#
#                                                                                                                                                                                                                                                                                                                              tags
# 0                                                                                                                            [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.transactionBetween100000And500000, transactionpattern.mostFrequentBalanceRange]
# 1                                               [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.recurringExpense, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
# 2  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.bankCharges, spend.ussdTransactions, behavioural.topRecipient, transactionpattern.recurringExpense, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
# 3                                                                            [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
# 4                                                                                             [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.airtime, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]

# %%
def extract_tags(data: pd.DataFrame, pattern: str) -> pd.Series:
    data = data.copy()

    result: np.ndarray = (
        data["tags"].astype("str").str.extract(pat=pattern, flags=re.I).to_numpy()
    ).flatten()
    result: pd.Series = pd.Series(data=result).astype(str)
    return result

# %%
df_1: pd.DataFrame = df.copy()

KEYWORD: str = "salary"
PATTERN: str = r"(salary\w{0,10})"
df_1[f"{KEYWORD}_label"] = extract_tags(data=df_1, pattern=PATTERN)

df_1.head()
# Out:
#   customer_id  nuban        date  \
# 0       40837      1  2022-04-19
# 1       39005      1  2022-08-30
# 2       40454      1  2022-07-05
# 3       39318      1  2022-07-08
# 4       38851      1  2022-04-09
#
#                                                           description  \
# 0  TRF/Ac/fan/FRM GIBSON PAUL U TO CHRIS-CHUKKAS ELECTRONICS LTD- 070
# 1                        TRF/Friday /FRM JONAH FRIDAY TO ONYENAUCHEYA
# 2                   Amt includes COMM & VAT/USSD/AISHAT ABIODUN BELLO
# 3       TRF/For clothes/FRM AJAKAYE WUNMI R TO OLALEYE OPEOLUWA LYDIA
# 4                                   WT|KODIRIC GLOBAL ENTERPRAMAC NG
#
#       amount type  \
# 0  163053.75    D
# 1    5010.75    D
# 2    3021.50    D
# 3   24000.00    D
# 4     100.00    D
#
#                                                                                                                                                                                                                                                                                                                              tags  \
# 0                                                                                                                            [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.transactionBetween100000And500000, transactionpattern.mostFrequentBalanceRange]
# 1                                               [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.recurringExpense, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
# 2  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.bankCharges, spend.ussdTransactions, behavioural.topRecipient, transactionpattern.recurringExpense, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
# 3                                                                            [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
# 4                                                                                             [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.airtime, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label
# 0          nan
# 1          nan
# 2          nan
# 3          nan
# 4          nan

# %%
KEYWORD: str = "loan"
PATTERN: str = r"(loan\w{0,10})"
df_1[f"{KEYWORD}_label"] = extract_tags(data=df_1, pattern=PATTERN)

df_1.head(2)
# Out:
#   customer_id  nuban        date  \
# 0       40837      1  2022-04-19
# 1       39005      1  2022-08-30
#
#                                                           description  \
# 0  TRF/Ac/fan/FRM GIBSON PAUL U TO CHRIS-CHUKKAS ELECTRONICS LTD- 070
# 1                        TRF/Friday /FRM JONAH FRIDAY TO ONYENAUCHEYA
#
#       amount type  \
# 0  163053.75    D
# 1    5010.75    D
#
#                                                                                                                                                                                                                                                                                 tags  \
# 0                                                                               [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.transactionBetween100000And500000, transactionpattern.mostFrequentBalanceRange]
# 1  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.recurringExpense, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label
# 0          nan        nan
# 1          nan        nan

# %%
KEYWORD: str = "gambling"
PATTERN: str = r"(gambling\w{0,5})"
df_1[f"{KEYWORD}_label"] = extract_tags(data=df_1, pattern=PATTERN)

df_1.head(2)
# Out:
#   customer_id  nuban        date  \
# 0       40837      1  2022-04-19
# 1       39005      1  2022-08-30
#
#                                                           description  \
# 0  TRF/Ac/fan/FRM GIBSON PAUL U TO CHRIS-CHUKKAS ELECTRONICS LTD- 070
# 1                        TRF/Friday /FRM JONAH FRIDAY TO ONYENAUCHEYA
#
#       amount type  \
# 0  163053.75    D
# 1    5010.75    D
#
#                                                                                                                                                                                                                                                                                 tags  \
# 0                                                                               [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.transactionBetween100000And500000, transactionpattern.mostFrequentBalanceRange]
# 1  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.recurringExpense, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label gambling_label
# 0          nan        nan            nan
# 1          nan        nan            nan

# %%
KEYWORD: str = "airtime"
PATTERN: str = r"(\w{0,5}airtime\w{0,5})"
df_1[f"{KEYWORD}_label"] = extract_tags(data=df_1, pattern=PATTERN)

df_1.head(2)
# Out:
#   customer_id  nuban        date  \
# 0       40837      1  2022-04-19
# 1       39005      1  2022-08-30
#
#                                                           description  \
# 0  TRF/Ac/fan/FRM GIBSON PAUL U TO CHRIS-CHUKKAS ELECTRONICS LTD- 070
# 1                        TRF/Friday /FRM JONAH FRIDAY TO ONYENAUCHEYA
#
#       amount type  \
# 0  163053.75    D
# 1    5010.75    D
#
#                                                                                                                                                                                                                                                                                 tags  \
# 0                                                                               [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.transactionBetween100000And500000, transactionpattern.mostFrequentBalanceRange]
# 1  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.recurringExpense, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label gambling_label airtime_label
# 0          nan        nan            nan           nan
# 1          nan        nan            nan           nan

# %%
KEYWORD: str = "ussdTransactions"
PATTERN: str = r"(ussd)"
df_1[f"{KEYWORD}_label"] = extract_tags(data=df_1, pattern=PATTERN)

df_1.head(2)
# Out:
#   customer_id  nuban        date  \
# 0       40837      1  2022-04-19
# 1       39005      1  2022-08-30
#
#                                                           description  \
# 0  TRF/Ac/fan/FRM GIBSON PAUL U TO CHRIS-CHUKKAS ELECTRONICS LTD- 070
# 1                        TRF/Friday /FRM JONAH FRIDAY TO ONYENAUCHEYA
#
#       amount type  \
# 0  163053.75    D
# 1    5010.75    D
#
#                                                                                                                                                                                                                                                                                 tags  \
# 0                                                                               [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.transactionBetween100000And500000, transactionpattern.mostFrequentBalanceRange]
# 1  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.recurringExpense, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label gambling_label airtime_label ussdTransactions_label
# 0          nan        nan            nan           nan                    nan
# 1          nan        nan            nan           nan                    nan

# %%
KEYWORD: str = "flightRisk"
PATTERN: str = r"(\w{0,10}flightRisk\w{0,10})"
df_1[f"{KEYWORD}_label"] = extract_tags(data=df_1, pattern=PATTERN)

df_1.head(2)
# Out:
#   customer_id  nuban        date  \
# 0       40837      1  2022-04-19
# 1       39005      1  2022-08-30
#
#                                                           description  \
# 0  TRF/Ac/fan/FRM GIBSON PAUL U TO CHRIS-CHUKKAS ELECTRONICS LTD- 070
# 1                        TRF/Friday /FRM JONAH FRIDAY TO ONYENAUCHEYA
#
#       amount type  \
# 0  163053.75    D
# 1    5010.75    D
#
#                                                                                                                                                                                                                                                                                 tags  \
# 0                                                                               [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.transactionBetween100000And500000, transactionpattern.mostFrequentBalanceRange]
# 1  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.recurringExpense, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label gambling_label airtime_label ussdTransactions_label  \
# 0          nan        nan            nan           nan                    nan
# 1          nan        nan            nan           nan                    nan
#
#   flightRisk_label
# 0              nan
# 1              nan

# %%
KEYWORD: str = "spendOnTransfers"
PATTERN: str = r"(\w{0,10}spendOnTransfers\w{0,10})"
df_1[f"{KEYWORD}_label"] = extract_tags(data=df_1, pattern=PATTERN)

df_1.head(2)
# Out:
#   customer_id  nuban        date  \
# 0       40837      1  2022-04-19
# 1       39005      1  2022-08-30
#
#                                                           description  \
# 0  TRF/Ac/fan/FRM GIBSON PAUL U TO CHRIS-CHUKKAS ELECTRONICS LTD- 070
# 1                        TRF/Friday /FRM JONAH FRIDAY TO ONYENAUCHEYA
#
#       amount type  \
# 0  163053.75    D
# 1    5010.75    D
#
#                                                                                                                                                                                                                                                                                 tags  \
# 0                                                                               [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.transactionBetween100000And500000, transactionpattern.mostFrequentBalanceRange]
# 1  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.recurringExpense, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label gambling_label airtime_label ussdTransactions_label  \
# 0          nan        nan            nan           nan                    nan
# 1          nan        nan            nan           nan                    nan
#
#   flightRisk_label spendOnTransfers_label
# 0              nan       spendOnTransfers
# 1              nan       spendOnTransfers

# %%
KEYWORD: str = "entertainment"
PATTERN: str = r"(entertainment\w{0,10})"
df_1[f"{KEYWORD}_label"] = extract_tags(data=df_1, pattern=PATTERN)

df_1.head(2)
# Out:
#   customer_id  nuban        date  \
# 0       40837      1  2022-04-19
# 1       39005      1  2022-08-30
#
#                                                           description  \
# 0  TRF/Ac/fan/FRM GIBSON PAUL U TO CHRIS-CHUKKAS ELECTRONICS LTD- 070
# 1                        TRF/Friday /FRM JONAH FRIDAY TO ONYENAUCHEYA
#
#       amount type  \
# 0  163053.75    D
# 1    5010.75    D
#
#                                                                                                                                                                                                                                                                                 tags  \
# 0                                                                               [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.transactionBetween100000And500000, transactionpattern.mostFrequentBalanceRange]
# 1  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.recurringExpense, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label gambling_label airtime_label ussdTransactions_label  \
# 0          nan        nan            nan           nan                    nan
# 1          nan        nan            nan           nan                    nan
#
#   flightRisk_label spendOnTransfers_label entertainment_label
# 0              nan       spendOnTransfers                 nan
# 1              nan       spendOnTransfers                 nan

# %%
KEYWORD: str = "spend"
PATTERN: str = r"(\w{0,40}spend)"
df_1[f"{KEYWORD}_label"] = extract_tags(data=df_1, pattern=PATTERN)

df_1.head(2)
# Out:
#   customer_id  nuban        date  \
# 0       40837      1  2022-04-19
# 1       39005      1  2022-08-30
#
#                                                           description  \
# 0  TRF/Ac/fan/FRM GIBSON PAUL U TO CHRIS-CHUKKAS ELECTRONICS LTD- 070
# 1                        TRF/Friday /FRM JONAH FRIDAY TO ONYENAUCHEYA
#
#       amount type  \
# 0  163053.75    D
# 1    5010.75    D
#
#                                                                                                                                                                                                                                                                                 tags  \
# 0                                                                               [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.transactionBetween100000And500000, transactionpattern.mostFrequentBalanceRange]
# 1  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.recurringExpense, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label gambling_label airtime_label ussdTransactions_label  \
# 0          nan        nan            nan           nan                    nan
# 1          nan        nan            nan           nan                    nan
#
#   flightRisk_label spendOnTransfers_label entertainment_label spend_label
# 0              nan       spendOnTransfers                 nan       spend
# 1              nan       spendOnTransfers                 nan       spend

# %%
KEYWORD: str = "bills"
PATTERN: str = r"(\w{0,10}bills\w{0,10})"
df_1[f"{KEYWORD}_label"] = extract_tags(data=df_1, pattern=PATTERN)

df_1.head(2)
# Out:
#   customer_id  nuban        date  \
# 0       40837      1  2022-04-19
# 1       39005      1  2022-08-30
#
#                                                           description  \
# 0  TRF/Ac/fan/FRM GIBSON PAUL U TO CHRIS-CHUKKAS ELECTRONICS LTD- 070
# 1                        TRF/Friday /FRM JONAH FRIDAY TO ONYENAUCHEYA
#
#       amount type  \
# 0  163053.75    D
# 1    5010.75    D
#
#                                                                                                                                                                                                                                                                                 tags  \
# 0                                                                               [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.transactionBetween100000And500000, transactionpattern.mostFrequentBalanceRange]
# 1  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.recurringExpense, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label gambling_label airtime_label ussdTransactions_label  \
# 0          nan        nan            nan           nan                    nan
# 1          nan        nan            nan           nan                    nan
#
#   flightRisk_label spendOnTransfers_label entertainment_label spend_label  \
# 0              nan       spendOnTransfers                 nan       spend
# 1              nan       spendOnTransfers                 nan       spend
#
#   bills_label
# 0         nan
# 1         nan

# %%
def extract_label(tags: list[str]) -> list[str]:
    """This is used to extract the tags from the list of tags."""
    result: list[str] = [val for val in tags if val != "nan"]
    if len(result) == 0:
        result = ["other"]
    return result

# %%
cols: list[str] = list(df_1.columns)[-10:]
df_1["list_labels"] = df_1.apply(lambda x: list(x[cols]), axis=1)

# %%
df_2: pd.DataFrame = df_1.copy()

df_2.head()
# Out:
#   customer_id  nuban        date  \
# 0       40837      1  2022-04-19
# 1       39005      1  2022-08-30
# 2       40454      1  2022-07-05
# 3       39318      1  2022-07-08
# 4       38851      1  2022-04-09
#
#                                                           description  \
# 0  TRF/Ac/fan/FRM GIBSON PAUL U TO CHRIS-CHUKKAS ELECTRONICS LTD- 070
# 1                        TRF/Friday /FRM JONAH FRIDAY TO ONYENAUCHEYA
# 2                   Amt includes COMM & VAT/USSD/AISHAT ABIODUN BELLO
# 3       TRF/For clothes/FRM AJAKAYE WUNMI R TO OLALEYE OPEOLUWA LYDIA
# 4                                   WT|KODIRIC GLOBAL ENTERPRAMAC NG
#
#       amount type  \
# 0  163053.75    D
# 1    5010.75    D
# 2    3021.50    D
# 3   24000.00    D
# 4     100.00    D
#
#                                                                                                                                                                                                                                                                                                                              tags  \
# 0                                                                                                                            [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.transactionBetween100000And500000, transactionpattern.mostFrequentBalanceRange]
# 1                                               [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.recurringExpense, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
# 2  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.bankCharges, spend.ussdTransactions, behavioural.topRecipient, transactionpattern.recurringExpense, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
# 3                                                                            [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
# 4                                                                                             [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.airtime, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label gambling_label airtime_label ussdTransactions_label  \
# 0          nan        nan            nan           nan                    nan
# 1          nan        nan            nan           nan                    nan
# 2          nan        nan            nan           nan                   ussd
# 3          nan        nan            nan           nan                    nan
# 4          nan        nan            nan       airtime                    nan
#
#   flightRisk_label spendOnTransfers_label entertainment_label spend_label  \
# 0              nan       spendOnTransfers                 nan       spend
# 1              nan       spendOnTransfers                 nan       spend
# 2              nan                    nan                 nan       spend
# 3              nan       spendOnTransfers                 nan       spend
# 4              nan                    nan                 nan       spend
#
#   bills_label  \
# 0         nan
# 1         nan
# 2         nan
# 3         nan
# 4         nan
#
#                                                          list_labels
# 0  [nan, nan, nan, nan, nan, nan, spendOnTransfers, nan, spend, nan]
# 1  [nan, nan, nan, nan, nan, nan, spendOnTransfers, nan, spend, nan]
# 2              [nan, nan, nan, nan, ussd, nan, nan, nan, spend, nan]
# 3  [nan, nan, nan, nan, nan, nan, spendOnTransfers, nan, spend, nan]
# 4           [nan, nan, nan, airtime, nan, nan, nan, nan, spend, nan]

# %%
df_2["cleaned_labels"] = df_2["list_labels"].apply(extract_label)

df_2.head(2)
# Out:
#   customer_id  nuban        date  \
# 0       40837      1  2022-04-19
# 1       39005      1  2022-08-30
#
#                                                           description  \
# 0  TRF/Ac/fan/FRM GIBSON PAUL U TO CHRIS-CHUKKAS ELECTRONICS LTD- 070
# 1                        TRF/Friday /FRM JONAH FRIDAY TO ONYENAUCHEYA
#
#       amount type  \
# 0  163053.75    D
# 1    5010.75    D
#
#                                                                                                                                                                                                                                                                                 tags  \
# 0                                                                               [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.transactionBetween100000And500000, transactionpattern.mostFrequentBalanceRange]
# 1  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.recurringExpense, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label gambling_label airtime_label ussdTransactions_label  \
# 0          nan        nan            nan           nan                    nan
# 1          nan        nan            nan           nan                    nan
#
#   flightRisk_label spendOnTransfers_label entertainment_label spend_label  \
# 0              nan       spendOnTransfers                 nan       spend
# 1              nan       spendOnTransfers                 nan       spend
#
#   bills_label  \
# 0         nan
# 1         nan
#
#                                                          list_labels  \
# 0  [nan, nan, nan, nan, nan, nan, spendOnTransfers, nan, spend, nan]
# 1  [nan, nan, nan, nan, nan, nan, spendOnTransfers, nan, spend, nan]
#
#               cleaned_labels
# 0  [spendOnTransfers, spend]
# 1  [spendOnTransfers, spend]

# %%
IMP_COLS: list[str] = ["date", "description", "amount", "type", "cleaned_labels"]
df_2 = df_2[IMP_COLS]

df_2.head()
# Out:
#          date  \
# 0  2022-04-19
# 1  2022-08-30
# 2  2022-07-05
# 3  2022-07-08
# 4  2022-04-09
#
#                                                           description  \
# 0  TRF/Ac/fan/FRM GIBSON PAUL U TO CHRIS-CHUKKAS ELECTRONICS LTD- 070
# 1                        TRF/Friday /FRM JONAH FRIDAY TO ONYENAUCHEYA
# 2                   Amt includes COMM & VAT/USSD/AISHAT ABIODUN BELLO
# 3       TRF/For clothes/FRM AJAKAYE WUNMI R TO OLALEYE OPEOLUWA LYDIA
# 4                                   WT|KODIRIC GLOBAL ENTERPRAMAC NG
#
#       amount type             cleaned_labels
# 0  163053.75    D  [spendOnTransfers, spend]
# 1    5010.75    D  [spendOnTransfers, spend]
# 2    3021.50    D              [ussd, spend]
# 3   24000.00    D  [spendOnTransfers, spend]
# 4     100.00    D           [airtime, spend]

# %%
def clean_salary(tags: list[str], type: str) -> list[str]:
    """This is used to clean the salary tags."""
    if type == "D":
        result: list[str] = [val for val in tags if val != "salaryEarner"]
        if len(result) == 0:
            result = ["other"]
    else:
        result = tags
    return result

# %%
df_2["cleaned_labels"] = df_2.apply(
    lambda x: clean_salary(tags=x["cleaned_labels"], type=x["type"]), axis=1
)

# %%
df_2["cleaned_labels"] = df_2["cleaned_labels"].str[0]

df_2.head()
# Out:
#          date  \
# 0  2022-04-19
# 1  2022-08-30
# 2  2022-07-05
# 3  2022-07-08
# 4  2022-04-09
#
#                                                           description  \
# 0  TRF/Ac/fan/FRM GIBSON PAUL U TO CHRIS-CHUKKAS ELECTRONICS LTD- 070
# 1                        TRF/Friday /FRM JONAH FRIDAY TO ONYENAUCHEYA
# 2                   Amt includes COMM & VAT/USSD/AISHAT ABIODUN BELLO
# 3       TRF/For clothes/FRM AJAKAYE WUNMI R TO OLALEYE OPEOLUWA LYDIA
# 4                                   WT|KODIRIC GLOBAL ENTERPRAMAC NG
#
#       amount type    cleaned_labels
# 0  163053.75    D  spendOnTransfers
# 1    5010.75    D  spendOnTransfers
# 2    3021.50    D              ussd
# 3   24000.00    D  spendOnTransfers
# 4     100.00    D           airtime

# %%
df_2["cleaned_labels"] = df_2["cleaned_labels"].apply(
    lambda x: "posOrWebSpend" if "pos" in x else ("posOrWebSpend" if "web" in x else x)
)

# %%
df_2.sample(n=20, random_state=8)
# Out:
#               date  \
# 609289  2022-11-06
# 433243  2022-10-09
# 467264  2022-08-01
# 649313  2021-10-14
# 533450  2021-11-24
# 527518  2022-11-09
# 702274  2022-09-25
# 695796  2022-08-12
# 290175  2022-10-11
# 785440  2022-11-08
# 76865   2022-03-04
# 60432   2022-06-01
# 415015  2022-01-08
# 471030  2021-12-23
# 178014  2022-07-08
# 113018  2022-11-01
# 544745  2023-01-03
# 568668  2021-11-21
# 618447  2022-04-04
# 351362  2022-10-19
#
#                                                                      description  \
# 609289                   Principal Liquidation 099ILAT222790188 2210060613129E15
# 433243           TRF//FRM ADEBOLA FUMILAYO TO  TEMITOPE OLUWASEUN IYEGBALE - 033
# 467264                    TRF/Sb/FRM ADEYEMI ADEFEMI TO  CHECKOUT PAYSTACK - 035
# 649313                                        FGN ELECTRONIC MONEY TRANSFER LEVY
# 533450                                                                   NEXTGEN
# 527518                                                  AIRTIME/ MTN/08134099813
# 702274                                 POS/WEB PMT OPAY DIGITAL SERVICE DL 00NG
# 695796  ATM WDL  @10442404 SOMOLU BRANCH LAGOS STATE, NG REF:920083/222417920083
# 290175             901 Airtime Topup/+2348066867340/USSDNWUSSD133099807188524394
# 785440           TRF/Boosting acc/FRM ADELEKE GANIYU ADE TO BEEBUH ZIMMY CONCEPT
# 76865        ASOGWA HARRISON UCHENNA/App  To Access Bank ASOGWA HARRISON UCHENNA
# 60432                CHARLES-ABU  OLUWATOYIN/USSD NIP Transfer from  08033215361
# 415015                                                                   NEXTGEN
# 471030                                                                   NEXTGEN
# 178014                                                       MUKAZ PROPERTIES/as
# 113018                  TRF/null/FRM HAFSAT ISMAILA HUSSAIN TO ZAKARIYAU ADEJARE
# 544745                 TRF//FRM NZEKWE KENECHUKWU TO ANTHONIA CHIDUM NZEKWE- 070
# 568668                                                                   NEXTGEN
# 618447     ATM WDL  @10443011 IJU BRANCH LAGOS STATE, NG REF:321137/209409321137
# 351362                            POS/WEB PMT OPAY_DIGITAL_SERVICES_LIKEJA 00NG
#
#                amount type    cleaned_labels
# 609289   98333.328125    D             other
# 433243    2010.750000    D  spendOnTransfers
# 467264   10026.879883    D  spendOnTransfers
# 649313     100.000000    D  spendOnTransfers
# 533450   34026.878906    D             other
# 527518     300.000000    D           airtime
# 702274    5600.000000    D             spend
# 695796   20000.000000    D    loanRepayments
# 290175     200.000000    D           airtime
# 785440   20000.000000    D  spendOnTransfers
# 76865    20000.000000    C             other
# 60432    12000.000000    C             other
# 415015     500.000000    D             other
# 471030    3610.750000    D             other
# 178014  100000.000000    C             other
# 113018   40000.000000    C      salaryEarner
# 544745   42026.878906    D  spendOnTransfers
# 568668    5010.750000    D             other
# 618447   20000.000000    D    loanRepayments
# 351362    5000.000000    D             spend

# %%
df_2["cleaned_labels"].value_counts(normalize=True)
# Out:
# other               0.397595
# spendOnTransfers    0.235674
# spend               0.148984
# airtime             0.110242
# ussd                0.063702
# loanRepayments      0.015315
# salaryEarner        0.012034
# gambling            0.007025
# loanAmount          0.006606
# flightRisk          0.002693
# entertainment       0.000130
# Name: cleaned_labels, dtype: float64

# %%
df_2.to_parquet("./my_data/trans_data_2.parquet", index=False)

# %% [markdown]
# ## Data Preparation For Sentence Classification

# %%
# Built-in library
import re
import json
import logging
from typing import Any, Dict, List, Optional, Union
import logging
import warnings

# Standard imports
import numpy as np
import pandas as pd
from rich import print
import torch

# Visualization
import matplotlib.pyplot as plt


# Pandas settings
pd.options.display.max_rows = 1_000
pd.options.display.max_columns = 1_000
pd.options.display.max_colwidth = 600

warnings.filterwarnings("ignore")

# Black code formatter (Optional)
# %load_ext lab_black

# auto reload imports
# %load_ext autoreload
# %autoreload 2

# %%
def set_up_logger(delim: str = "::") -> Any:
    """This is used to create a basic logger."""

    format_ = f"[%(levelname)s] {delim} %(asctime)s {delim} %(message)s"
    logging.basicConfig(level=logging.INFO, format=format_)
    logger = logging.getLogger(__name__)
    return logger


# Global variable
logger = set_up_logger()


def load_data(*, filename: str, sep: str = ",") -> pd.DataFrame:
    """This is used to load the data.

    NB: Supported formats are 'csv' and 'parquet'.

    Params:
    -------
        filename (str): The filepath.
        sep (str, default=","): The separator. e.g ',', '\t', etc

    Returns:
    --------
        data (pd.DataFrame): The loaded dataframe.
    """
    data = (
        pd.read_csv(filename, sep=sep)
        if filename.split(".")[-1] == "csv"
        else pd.read_parquet(filename)
    )
    logger.info(f"Shape of data: {data.shape}\n")
    return data

# %% [markdown]
# ### Prepare Data
#
# ```text
# Create:
# - Training data
# - Validation data
# - Test data
#
# Labels
# ------
# salary
# gambling
# loan
# airtime
# ussdTransactions
# flightRisk
# savingsAndInvestments
# entertainment
# spend
#   - posSpend
#   - atmSpend
#   - mobileSpend
#   - webSpend
# ```

# %%
fp: str = "../../data/trans_TAGS_24.parquet"
N: int = 500_000
df: pd.DataFrame = (
    load_data(filename=fp).sample(n=N, random_state=123).reset_index(drop=True)
)

df.head()
# Out:
# [INFO] :: 2023-10-27 23:41:44,243 :: Shape of data: (2355234, 7)
#   customer_id  nuban        date  \
# 0       55844      1  2022-05-29
# 1       56822      1  2022-03-19
# 2       56251      1  2022-01-14
# 3       55465      1  2022-02-19
# 4       56980      1  2022-05-28
#
#                                            description        amount type  \
# 0  POS/WEB PMT T MODERNCOMMUNICATI 000104 2070849Y NG   20000.000000    D
# 1                              POS/WEB PMT NULL LA NG   13100.000000    D
# 2                   FGN ELECTRONIC MONEY TRANSFER LEVY    100.000000    D
# 3                                         Quantum USSD  20026.880859    D
# 4          POS/WEB PMT BETWAY NG/1853277904 PSTK LANG   10000.000000    D
#
#                                                                                                                                                                                                                                                                            tags
# 0                                                                   [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
# 1                                                                   [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
# 2                                                                                   [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentBalanceRange]
# 3                                                                           [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.ussdTransactions, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
# 4  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.gambling, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]

# %%
def extract_tags(data: pd.DataFrame, pattern: str) -> pd.Series:
    data = data.copy()

    result: np.ndarray = (
        data["tags"].astype("str").str.extract(pat=pattern, flags=re.I).to_numpy()
    ).flatten()
    result: pd.Series = pd.Series(data=result).astype(str)
    return result

# %%
df_1: pd.DataFrame = df.copy()

KEYWORD: str = "salary"
PATTERN: str = r"(salary\w{0,10})"
df_1[f"{KEYWORD}_label"] = extract_tags(data=df_1, pattern=PATTERN)

df_1.head()
# Out:
#   customer_id  nuban        date  \
# 0       55844      1  2022-05-29
# 1       56822      1  2022-03-19
# 2       56251      1  2022-01-14
# 3       55465      1  2022-02-19
# 4       56980      1  2022-05-28
#
#                                            description        amount type  \
# 0  POS/WEB PMT T MODERNCOMMUNICATI 000104 2070849Y NG   20000.000000    D
# 1                              POS/WEB PMT NULL LA NG   13100.000000    D
# 2                   FGN ELECTRONIC MONEY TRANSFER LEVY    100.000000    D
# 3                                         Quantum USSD  20026.880859    D
# 4          POS/WEB PMT BETWAY NG/1853277904 PSTK LANG   10000.000000    D
#
#                                                                                                                                                                                                                                                                            tags  \
# 0                                                                   [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
# 1                                                                   [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
# 2                                                                                   [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentBalanceRange]
# 3                                                                           [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.ussdTransactions, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
# 4  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.gambling, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label
# 0          nan
# 1          nan
# 2          nan
# 3          nan
# 4          nan

# %%
KEYWORD: str = "loan"
PATTERN: str = r"(loan\w{0,10})"
df_1[f"{KEYWORD}_label"] = extract_tags(data=df_1, pattern=PATTERN)

df_1.head(2)
# Out:
#   customer_id  nuban        date  \
# 0       55844      1  2022-05-29
# 1       56822      1  2022-03-19
#
#                                            description   amount type  \
# 0  POS/WEB PMT T MODERNCOMMUNICATI 000104 2070849Y NG   20000.0    D
# 1                              POS/WEB PMT NULL LA NG   13100.0    D
#
#                                                                                                                                                                                                           tags  \
# 0  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
# 1  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label
# 0          nan        nan
# 1          nan        nan

# %%
KEYWORD: str = "gambling"
PATTERN: str = r"(gambling\w{0,5})"
df_1[f"{KEYWORD}_label"] = extract_tags(data=df_1, pattern=PATTERN)

df_1.head(2)
# Out:
#   customer_id  nuban        date  \
# 0       55844      1  2022-05-29
# 1       56822      1  2022-03-19
#
#                                            description   amount type  \
# 0  POS/WEB PMT T MODERNCOMMUNICATI 000104 2070849Y NG   20000.0    D
# 1                              POS/WEB PMT NULL LA NG   13100.0    D
#
#                                                                                                                                                                                                           tags  \
# 0  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
# 1  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label gambling_label
# 0          nan        nan            nan
# 1          nan        nan            nan

# %%
KEYWORD: str = "airtime"
PATTERN: str = r"(\w{0,5}airtime\w{0,5})"
df_1[f"{KEYWORD}_label"] = extract_tags(data=df_1, pattern=PATTERN)

df_1.head(2)
# Out:
#   customer_id  nuban        date  \
# 0       55844      1  2022-05-29
# 1       56822      1  2022-03-19
#
#                                            description   amount type  \
# 0  POS/WEB PMT T MODERNCOMMUNICATI 000104 2070849Y NG   20000.0    D
# 1                              POS/WEB PMT NULL LA NG   13100.0    D
#
#                                                                                                                                                                                                           tags  \
# 0  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
# 1  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label gambling_label airtime_label
# 0          nan        nan            nan           nan
# 1          nan        nan            nan           nan

# %%
KEYWORD: str = "ussdTransactions"
PATTERN: str = r"(ussd)"
df_1[f"{KEYWORD}_label"] = extract_tags(data=df_1, pattern=PATTERN)

df_1.head(2)
# Out:
#   customer_id  nuban        date  \
# 0       55844      1  2022-05-29
# 1       56822      1  2022-03-19
#
#                                            description   amount type  \
# 0  POS/WEB PMT T MODERNCOMMUNICATI 000104 2070849Y NG   20000.0    D
# 1                              POS/WEB PMT NULL LA NG   13100.0    D
#
#                                                                                                                                                                                                           tags  \
# 0  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
# 1  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label gambling_label airtime_label ussdTransactions_label
# 0          nan        nan            nan           nan                    nan
# 1          nan        nan            nan           nan                    nan

# %%
KEYWORD: str = "flightRisk"
PATTERN: str = r"(\w{0,10}flightRisk\w{0,10})"
df_1[f"{KEYWORD}_label"] = extract_tags(data=df_1, pattern=PATTERN)

df_1.head(2)
# Out:
#   customer_id  nuban        date  \
# 0       55844      1  2022-05-29
# 1       56822      1  2022-03-19
#
#                                            description   amount type  \
# 0  POS/WEB PMT T MODERNCOMMUNICATI 000104 2070849Y NG   20000.0    D
# 1                              POS/WEB PMT NULL LA NG   13100.0    D
#
#                                                                                                                                                                                                           tags  \
# 0  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
# 1  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label gambling_label airtime_label ussdTransactions_label  \
# 0          nan        nan            nan           nan                    nan
# 1          nan        nan            nan           nan                    nan
#
#   flightRisk_label
# 0              nan
# 1              nan

# %%
KEYWORD: str = "spendOnTransfers"
PATTERN: str = r"(\w{0,10}spendOnTransfers\w{0,10})"
df_1[f"{KEYWORD}_label"] = extract_tags(data=df_1, pattern=PATTERN)

df_1.head(2)
# Out:
#   customer_id  nuban        date  \
# 0       55844      1  2022-05-29
# 1       56822      1  2022-03-19
#
#                                            description   amount type  \
# 0  POS/WEB PMT T MODERNCOMMUNICATI 000104 2070849Y NG   20000.0    D
# 1                              POS/WEB PMT NULL LA NG   13100.0    D
#
#                                                                                                                                                                                                           tags  \
# 0  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
# 1  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label gambling_label airtime_label ussdTransactions_label  \
# 0          nan        nan            nan           nan                    nan
# 1          nan        nan            nan           nan                    nan
#
#   flightRisk_label spendOnTransfers_label
# 0              nan                    nan
# 1              nan                    nan

# %%
KEYWORD: str = "entertainment"
PATTERN: str = r"(entertainment\w{0,10})"
df_1[f"{KEYWORD}_label"] = extract_tags(data=df_1, pattern=PATTERN)

df_1.head(2)
# Out:
#   customer_id  nuban        date  \
# 0       55844      1  2022-05-29
# 1       56822      1  2022-03-19
#
#                                            description   amount type  \
# 0  POS/WEB PMT T MODERNCOMMUNICATI 000104 2070849Y NG   20000.0    D
# 1                              POS/WEB PMT NULL LA NG   13100.0    D
#
#                                                                                                                                                                                                           tags  \
# 0  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
# 1  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label gambling_label airtime_label ussdTransactions_label  \
# 0          nan        nan            nan           nan                    nan
# 1          nan        nan            nan           nan                    nan
#
#   flightRisk_label spendOnTransfers_label entertainment_label
# 0              nan                    nan                 nan
# 1              nan                    nan                 nan

# %%
KEYWORD: str = "spend"
PATTERN: str = r"(\w{0,40}spend)"
df_1[f"{KEYWORD}_label"] = extract_tags(data=df_1, pattern=PATTERN)

df_1.head(2)
# Out:
#   customer_id  nuban        date  \
# 0       55844      1  2022-05-29
# 1       56822      1  2022-03-19
#
#                                            description   amount type  \
# 0  POS/WEB PMT T MODERNCOMMUNICATI 000104 2070849Y NG   20000.0    D
# 1                              POS/WEB PMT NULL LA NG   13100.0    D
#
#                                                                                                                                                                                                           tags  \
# 0  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
# 1  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label gambling_label airtime_label ussdTransactions_label  \
# 0          nan        nan            nan           nan                    nan
# 1          nan        nan            nan           nan                    nan
#
#   flightRisk_label spendOnTransfers_label entertainment_label spend_label
# 0              nan                    nan                 nan       spend
# 1              nan                    nan                 nan       spend

# %%
KEYWORD: str = "bills"
PATTERN: str = r"(\w{0,10}bills\w{0,10})"
df_1[f"{KEYWORD}_label"] = extract_tags(data=df_1, pattern=PATTERN)

df_1.head(2)
# Out:
#   customer_id  nuban        date  \
# 0       55844      1  2022-05-29
# 1       56822      1  2022-03-19
#
#                                            description   amount type  \
# 0  POS/WEB PMT T MODERNCOMMUNICATI 000104 2070849Y NG   20000.0    D
# 1                              POS/WEB PMT NULL LA NG   13100.0    D
#
#                                                                                                                                                                                                           tags  \
# 0  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
# 1  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label gambling_label airtime_label ussdTransactions_label  \
# 0          nan        nan            nan           nan                    nan
# 1          nan        nan            nan           nan                    nan
#
#   flightRisk_label spendOnTransfers_label entertainment_label spend_label  \
# 0              nan                    nan                 nan       spend
# 1              nan                    nan                 nan       spend
#
#   bills_label
# 0         nan
# 1         nan

# %%
def extract_label(tags: list[str]) -> list[str]:
    """This is used to extract the tags from the list of tags."""
    result: list[str] = [val for val in tags if val != "nan"]
    if len(result) == 0:
        result = ["other"]
    return result

# %%
cols: list[str] = list(df_1.columns)[-10:]
df_1["list_labels"] = df_1.apply(lambda x: list(x[cols]), axis=1)

# %%
df_2: pd.DataFrame = df_1.copy()

df_2.head()
# Out:
#   customer_id  nuban        date  \
# 0       55844      1  2022-05-29
# 1       56822      1  2022-03-19
# 2       56251      1  2022-01-14
# 3       55465      1  2022-02-19
# 4       56980      1  2022-05-28
#
#                                            description        amount type  \
# 0  POS/WEB PMT T MODERNCOMMUNICATI 000104 2070849Y NG   20000.000000    D
# 1                              POS/WEB PMT NULL LA NG   13100.000000    D
# 2                   FGN ELECTRONIC MONEY TRANSFER LEVY    100.000000    D
# 3                                         Quantum USSD  20026.880859    D
# 4          POS/WEB PMT BETWAY NG/1853277904 PSTK LANG   10000.000000    D
#
#                                                                                                                                                                                                                                                                            tags  \
# 0                                                                   [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
# 1                                                                   [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
# 2                                                                                   [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.spendOnTransfers, transactionpattern.transactionLessThan10000, transactionpattern.mostFrequentBalanceRange]
# 3                                                                           [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.ussdTransactions, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
# 4  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.gambling, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentTransactionRange, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label gambling_label airtime_label ussdTransactions_label  \
# 0          nan        nan            nan           nan                    nan
# 1          nan        nan            nan           nan                    nan
# 2          nan        nan            nan           nan                    nan
# 3          nan        nan            nan           nan                   ussd
# 4          nan        nan       gambling           nan                    nan
#
#   flightRisk_label spendOnTransfers_label entertainment_label spend_label  \
# 0              nan                    nan                 nan       spend
# 1              nan                    nan                 nan       spend
# 2              nan       spendOnTransfers                 nan       spend
# 3              nan                    nan                 nan       spend
# 4              nan                    nan                 nan       spend
#
#   bills_label  \
# 0         nan
# 1         nan
# 2         nan
# 3         nan
# 4         nan
#
#                                                          list_labels
# 0               [nan, nan, nan, nan, nan, nan, nan, nan, spend, nan]
# 1               [nan, nan, nan, nan, nan, nan, nan, nan, spend, nan]
# 2  [nan, nan, nan, nan, nan, nan, spendOnTransfers, nan, spend, nan]
# 3              [nan, nan, nan, nan, ussd, nan, nan, nan, spend, nan]
# 4          [nan, nan, gambling, nan, nan, nan, nan, nan, spend, nan]

# %%
df_2["cleaned_labels"] = df_2["list_labels"].apply(extract_label)

df_2.head(2)
# Out:
#   customer_id  nuban        date  \
# 0       55844      1  2022-05-29
# 1       56822      1  2022-03-19
#
#                                            description   amount type  \
# 0  POS/WEB PMT T MODERNCOMMUNICATI 000104 2070849Y NG   20000.0    D
# 1                              POS/WEB PMT NULL LA NG   13100.0    D
#
#                                                                                                                                                                                                           tags  \
# 0  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
# 1  [balance, behavioural.accountSweep, behavioural.inflowOutflowRate, debit, spend.posSpend, spend.webSpend, transactionpattern.transactionBetween10000And100000, transactionpattern.mostFrequentBalanceRange]
#
#   salary_label loan_label gambling_label airtime_label ussdTransactions_label  \
# 0          nan        nan            nan           nan                    nan
# 1          nan        nan            nan           nan                    nan
#
#   flightRisk_label spendOnTransfers_label entertainment_label spend_label  \
# 0              nan                    nan                 nan       spend
# 1              nan                    nan                 nan       spend
#
#   bills_label                                           list_labels  \
# 0         nan  [nan, nan, nan, nan, nan, nan, nan, nan, spend, nan]
# 1         nan  [nan, nan, nan, nan, nan, nan, nan, nan, spend, nan]
#
#   cleaned_labels
# 0        [spend]
# 1        [spend]

# %%
IMP_COLS: list[str] = ["date", "description", "amount", "type", "cleaned_labels"]
df_2 = df_2[IMP_COLS]

df_2.head()
# Out:
#          date                                          description  \
# 0  2022-05-29  POS/WEB PMT T MODERNCOMMUNICATI 000104 2070849Y NG
# 1  2022-03-19                              POS/WEB PMT NULL LA NG
# 2  2022-01-14                   FGN ELECTRONIC MONEY TRANSFER LEVY
# 3  2022-02-19                                         Quantum USSD
# 4  2022-05-28          POS/WEB PMT BETWAY NG/1853277904 PSTK LANG
#
#          amount type             cleaned_labels
# 0  20000.000000    D                    [spend]
# 1  13100.000000    D                    [spend]
# 2    100.000000    D  [spendOnTransfers, spend]
# 3  20026.880859    D              [ussd, spend]
# 4  10000.000000    D          [gambling, spend]

# %%
def clean_salary(tags: list[str], type: str) -> list[str]:
    """This is used to clean the salary tags."""
    if type == "D":
        result: list[str] = [val for val in tags if val != "salaryEarner"]
        if len(result) == 0:
            result = ["other"]
    else:
        result = tags
    return result

# %%
df_2["cleaned_labels"] = df_2.apply(
    lambda x: clean_salary(tags=x["cleaned_labels"], type=x["type"]), axis=1
)

# %%
df_2["cleaned_labels"] = df_2["cleaned_labels"].str[0]

df_2.head()
# Out:
#          date                                          description  \
# 0  2022-05-29  POS/WEB PMT T MODERNCOMMUNICATI 000104 2070849Y NG
# 1  2022-03-19                              POS/WEB PMT NULL LA NG
# 2  2022-01-14                   FGN ELECTRONIC MONEY TRANSFER LEVY
# 3  2022-02-19                                         Quantum USSD
# 4  2022-05-28          POS/WEB PMT BETWAY NG/1853277904 PSTK LANG
#
#          amount type    cleaned_labels
# 0  20000.000000    D             spend
# 1  13100.000000    D             spend
# 2    100.000000    D  spendOnTransfers
# 3  20026.880859    D              ussd
# 4  10000.000000    D          gambling

# %%
df_2["cleaned_labels"] = df_2["cleaned_labels"].apply(
    lambda x: "posOrWebSpend" if "pos" in x else ("posOrWebSpend" if "web" in x else x)
)

# %%
df_2.sample(n=20, random_state=8)
# Out:
#               date  \
# 428765  2022-12-17
# 354568  2022-02-20
# 353541  2022-09-17
# 129905  2022-09-07
# 83894   2022-06-09
# 166168  2022-08-06
# 156584  2022-06-28
# 115509  2022-06-09
# 86146   2022-09-12
# 491511  2022-05-14
# 67806   2022-04-04
# 47019   2022-02-22
# 467976  2022-10-10
# 279958  2022-07-10
# 424009  2022-06-21
# 456646  2022-03-29
# 164454  2022-08-04
# 245243  2021-12-27
# 483299  2022-04-09
# 196197  2022-08-27
#
#                                                                                                       description  \
# 428765                                                               Amt includes COMM & VAT/USSD/ANDRIYA YUSUF D
# 354568                                                          TRF//FRM ABASS KOLAPO TO ADISA ABASS AKOREDE- 011
# 353541                                              AGU CHIKELUBA NEWMAN/MOB/CHIJIOKE GODWIN/UTO/12625657631/Eedc
# 129905                                                                                  T933984 2TAB11TS LA LANG
# 83894                                                        TRF/Food/FRM QUEEN  OKAKA TO OHUE MARY IKAEHOTA- 058
# 166168                                         TRF//FRM PRINCE UDE OGBONNAYA TO A.K.AUSCA INVESTMENT COY.LTD- 011
# 156584                                                    TRF//FRM ANYIKWA IFEANYI TO  FAVOUR ADINDU VIVIAN - 033
# 115509                                                                         FGN ELECTRONIC MONEY TRANSFER LEVY
# 86146                                            TRF//FRM ADEDEJI CHRISTOPHER TO  ABOSEDE OLUWATOSIN DAHUNSI- 076
# 491511                       TRF/Loan/FRM HAMZAT ABIODUN MUBAR TO  (IBADAN) AL-AMANAH INTEREST FREE MONATAN - 301
# 67806                                                               Amt includes COMM & VAT/USSD_NIP/YAHUZA GARBA
# 47019                                                            TRF//FRM RASHEED DAUDA TO PAYSTACK CHECKOUT- 035
# 467976                                                             POS/WEB PMT OPAY_DIGITAL_SERVICES_LIKEJA 00NG
# 279958                                                                         FGN ELECTRONIC MONEY TRANSFER LEVY
# 424009  GREENHILL PHARMACEUTICALS LIMITED/Transfer from GREENHILL PHARMACEUTICALS LIMITED to ADEBAYO ABAYOMI ABEL
# 456646                                                 Amt includes COMM & VAT/USSD_NIP/AMIRE  EZEKIEL OLUWASANMI
# 164454                                                                                   AIRTIME/ MTN/07031182017
# 245243                                                                                            POS/WEB TRF ROU
# 483299                                                                  000089449255/E770 TRF FRM KAZEEM MUHAMME
# 196197                                                                               AIRTIME/ 9MOBILE/08184349634
#
#                amount type    cleaned_labels
# 428765     500.000000    C             other
# 354568   15026.879883    D  spendOnTransfers
# 353541   20000.000000    C             other
# 129905  160000.000000    D             other
# 83894     1510.750000    D  spendOnTransfers
# 166168    2010.750000    D  spendOnTransfers
# 156584    2010.750000    D  spendOnTransfers
# 115509      50.000000    D  spendOnTransfers
# 86146     2010.750000    D  spendOnTransfers
# 491511   57553.750000    D    loanRepayments
# 67806    20026.880859    D              ussd
# 47019     1010.750000    D  spendOnTransfers
# 467976   10200.000000    D             spend
# 279958      50.000000    D  spendOnTransfers
# 424009   24500.000000    C             other
# 456646    1710.750000    D              ussd
# 164454      30.000000    D           airtime
# 245243    3000.000000    C             other
# 483299   17000.000000    C             other
# 196197    2000.000000    D           airtime

# %%
df_2["cleaned_labels"].value_counts(normalize=True)
# Out:
# other               0.410990
# spendOnTransfers    0.222586
# spend               0.144992
# airtime             0.110922
# ussd                0.067908
# loanRepayments      0.013126
# salaryEarner        0.010738
# gambling            0.010120
# loanAmount          0.005898
# flightRisk          0.002578
# entertainment       0.000142
# Name: cleaned_labels, dtype: float64

# %%
df_2.to_parquet("./my_data/trans_data.parquet", index=False)
